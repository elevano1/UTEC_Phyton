# %% [markdown]
# <a href="https://colab.research.google.com/github/elevano1/UTEC_Phyton/blob/main/modulo-III/sesi_n_4_ejercicios__student_view.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![picture](https://drive.google.com/uc?export=view&id=1KaUW3_JAieeY7WVNfoRiTSr2JsaeAcXi)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Ejercícios
# # Módulo 3 - Sesión 4
# ## Profesor: Germain Garcia Zanabria
#
# ### Indicaciones
#
# Completa las secciones de código en las que se indique `### Completar`. Siga las instrucciones y proporcione la implementación adecuada en cada caso. Si necesitas ayuda o tienes alguna pregunta, no dudes en levantar la mano para que pueda asistirte.

# %% [markdown]
# # Ejercicio 1. Gráficos de Funciones

# %%
# Ejercicio 1.1
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(-10, 10, 400)
y = x ** 2

plt.plot(x, y, label='y = x^2')
plt.title('Gráfico de la función y = x^2')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# Ejercicio 1.2
x = np.linspace(0, 2 * np.pi, 400)
y_sin = ### Completar
y_cos = ### Completar

plt.plot(x, y_sin, label='y = sin(x)')
plt.plot(x, y_cos, label='y = cos(x)')
plt.title('Gráfico de las funciones y = sin(x) y y = cos(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# Ejercicio 1.3
x = np.linspace(-2, 2, 400)
y = ### Completar

plt.plot(x, y, label='y = e^x')
plt.title('Gráfico de la función y = e^x')
plt.xlabel('x')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Ejercicio American Ninja Warrior

# %%
# Conectar con Google Drive

try:
    from google.colab import drive
    drive.mount('/content/drive')
    PATH = '/content/drive/MyDrive/'    # Cambiar a: '/content/drive/MyDrive/'
except:
    PATH = '../'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from IPython.display import display
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET

df = pd.read_excel(PATH + "American Ninja Warrior Obstacle History.xlsx")


df.head()
# Out:
#    Season Location Round_or_Stage    Obstacle_Name  Obstacle_Order
# 0       1   Venice     Qualifying  Quintuple Steps               1
# 1       1   Venice     Qualifying       Rope Swing               2
# 2       1   Venice     Qualifying   Rolling Barrel               3
# 3       1   Venice     Qualifying   Jumping Spider               4
# 4       1   Venice     Qualifying      Pipe Slider               5

# %% [markdown]
# ## Histograma del Orden de los Obstáculos en American Ninja Warrior

# %%
import matplotlib.pyplot as plt

# Crear el histograma
plt.hist(### Completar, bins=10 )
plt.xlabel('Orden de los Obstáculos')
plt.ylabel('Frecuencia')
plt.title('Histograma del Orden de los Obstáculos en American Ninja Warrior')
plt.show()

# %% [markdown]
# ## Gráfico de Líneas

# %%
# Agrupa los datos por temporada y calcula el promedio del orden de los obstáculos para cada temporada
obstaculos_por_temporada = df.groupby('Season')['Obstacle_Order'].### Completar() ### Completar calcula el promedio de esta columna

# Extrae las temporadas (índices) del resultado del agrupamiento
temporadas = obstaculos_por_temporada.index

plt.plot(### Completar, obstaculos_por_temporada, marker='o')
plt.xlabel('Temporada')
plt.ylabel('Orden Promedio de Obstáculos')
plt.title('Evolución del Orden Promedio de Obstáculos por Temporada')
plt.xticks(temporadas)
plt.grid(True)
plt.show()

# %% [markdown]
# # Subplots

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 6))

# Histograma
ax1.hist(df['Obstacle_Order'], bins=10, edgecolor='black')
ax1.set_xlabel('Orden de los Obstáculos')
ax1.set_ylabel('Frecuencia')
ax1.set_title('Histograma del Orden de los Obstáculos')

# Gráfico de líneas
obstaculos_por_temporada = df.groupby('Season')['Obstacle_Order'].mean()
temporadas = obstaculos_por_temporada.index
ax2.plot(temporadas, obstaculos_por_temporada, marker='o')
ax2.set_xlabel('Temporada')
ax2.set_ylabel('Orden Promedio de Obstáculos')
ax2.set_title('Evolución del Orden Promedio de Obstáculos por Temporada')
ax2.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Diagrama de Caja
# Genera un diagrama de caja del orden de los obstáculos (Obstacle_order):

# %%
plt.boxplot(df[### Completar])  ### Completar con nombre de columna  Obstacle_Order
plt.xlabel('Orden de los Obstáculos')
plt.ylabel('Valor')
plt.title('Diagrama de Caja del Orden de los Obstáculos')
plt.show()

# %% [markdown]
# ## Gráfico de Pie

# %%
conteo_rondas = df['Round_or_Stage'].value_counts()  ### Completar
plt.pie(conteo_rondas, labels=conteo_rondas.index, autopct='%1.1f%%', startangle=140)
plt.axis('equal')
plt.title('Distribución de Rondas o Etapas en American Ninja Warrior')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Round_or_Stage'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-18-c120f2b0d3e0> in <cell line: 0>()
# ...

# %% [markdown]
# # Ejemplito simple

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/germaingarcia/diplomadoFiles/main/conjunto_datos%20(2).csv')
df.head()
# Out:
#    Grado_Simpatico  Regalos_Realizados  Te_habla_de_sus_citas  \
# 0              5.0                 0.0                    5.0
# 1              2.0                 6.0                    2.0
# 2             10.0                 5.0                    4.0
# 3              4.0                 2.0                    6.0
# 4              5.0                 5.0                    4.0
#
#    Tiempo_dedicado  Amigos_presentados  Veces_que_quedais_a_solas  \
# 0              3.0                 8.0                       10.0
# 1              3.0                 7.0                        5.0
# 2              9.0                 3.0                        4.0
# 3              8.0                 8.0                        8.0
# 4              0.0                 8.0                        5.0
#
#    Consejos_dados  FRIENZONEADO
# 0             4.0             0
# 1             7.0             1
# 2             7.0             1
# 3             3.0             0
# ...

# %%
df.corr()
# Out:
#                            Grado_Simpatico  Regalos_Realizados  \
# Grado_Simpatico                   1.000000            0.300418
# Regalos_Realizados                0.300418            1.000000
# Te_habla_de_sus_citas            -0.063917           -0.058127
# Tiempo_dedicado                   0.112624           -0.041275
# Amigos_presentados                0.050356           -0.098116
# Veces_que_quedais_a_solas        -0.273252           -0.797164
# Consejos_dados                    0.133443            0.367097
# FRIENZONEADO                      0.373551            0.794710
#
#                            Te_habla_de_sus_citas  Tiempo_dedicado  \
# Grado_Simpatico                        -0.063917         0.112624
# Regalos_Realizados                     -0.058127        -0.041275
# Te_habla_de_sus_citas                   1.000000         0.033261
# Tiempo_dedicado                         0.033261         1.000000
# ...

# %%
# graficar la correlación
import seaborn as sns

sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
# Out:
# <Axes: >

# %%
df_frienzone = df[df['FRIENZONEADO']== 1] #completar
df_NO_frienzone = df[df['FRIENZONEADO']== 0]#completar

# %%
df_frienzone # :(
# Out:
#     Grado_Simpatico  Regalos_Realizados  Te_habla_de_sus_citas  \
# 1               2.0                 6.0                    2.0
# 2              10.0                 5.0                    4.0
# 4               5.0                 5.0                    4.0
# 5               3.0                 6.0                    7.0
# 6               8.0                 7.0                    5.0
# 7               5.0                 4.0                    3.0
# 8               6.0                 8.0                    4.0
# 9               1.0                 8.0                    7.0
# 10              7.0                 6.0                    7.0
# 13             10.0                 8.0                    8.0
# 19              7.0                 6.0                    9.0
# 21              3.0                 8.0                    2.0
# 22              2.0                 4.0                   10.0
# 25              6.0                 8.0                    3.0
# ...

# %%
df.columns
# Out:
# Index(['Grado_Simpatico', 'Regalos_Realizados', 'Te_habla_de_sus_citas',
#        'Tiempo_dedicado', 'Amigos_presentados', 'Veces_que_quedais_a_solas',
#        'Consejos_dados', 'FRIENZONEADO'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 5))

# Plotting the boxplot
lista = ["Grado_Simpatico","Regalos_Realizados","Te_habla_de_sus_citas","Tiempo_dedicado","Amigos_presentados","Veces_que_quedais_a_solas","Consejos_dados"]
df_frienzone[lista].boxplot()

plt.title('Box Plot para Friendzoneado')
plt.xlabel('Variables')
plt.ylabel('Valores')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(8, 5))
df_NO_frienzone[lista].boxplot()
plt.title('Box Plot para NO frienzoneado')
plt.xlabel('Variables')
plt.ylabel('Valores')
plt.xticks(rotation=45)
plt.tight_layout()

plt.show()
