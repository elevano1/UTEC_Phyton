# %% [markdown]
# <a href="https://colab.research.google.com/github/elevano1/UTEC_Phyton/blob/main/modulo-III/S4_Ejemplos_%2B_Datosaurus.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![picture](https://drive.google.com/uc?export=view&id=1KaUW3_JAieeY7WVNfoRiTSr2JsaeAcXi)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Ejemplos + Datosaurus
# # Módulo 3 - Sesión 4
# ## Profesor: Germain Garcia Zanabria

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

plt.plot(x,y,marker='o',linestyle = '-.',color = '#fb8072', label = 'Hola')
plt.title("Hola este es un título")
plt.xlabel("Eje X")
plt.ylabel("Eje Y")
plt.legend()
plt.grid(True)
plt.show() # crea la imagen, es como el print

# %%
import matplotlib.pyplot as plt

# Datos de ejemplo
x = [1, 2, 3, 4, 5]
y = [2, 3, 5, 7, 11]

# Crear el gráfico
plt.plot(x, y, marker='o', linestyle='-.', color='#80b1d3', label='Crecimiento') # '-', '--', '-.', ':', 'None', ' ', '', 'solid', 'dashed', 'dashdot', 'dotted'

"""
# Añadir etiquetas y título
plt.xlabel('Días')  # Etiqueta del eje X
plt.ylabel('Valores')  # Etiqueta del eje Y
plt.title('Ejemplo de Gráfico de Líneas')  # Título del gráfico
plt.legend()  # Mostrar leyenda
"""
plt.xlabel('Días')  # Etiqueta del eje X
plt.ylabel('Valores')  # Etiqueta del eje Y
plt.title('Ejemplo de Gráfico de Líneas')  # Título del gráfico
plt.legend()  # Mostrar leyenda
# Añadir líneas de la cuadrícula
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Función Cuadrática

# %%
import numpy as np

# Parámetros de la función cuadrática
a, b, c = 1, -3, 2
x = np.linspace(-10, 20, 40)
y = a * x**2 + b * x + c

plt.plot(x, y,linestyle='-.')
plt.title('Función Cuadrática')
plt.xlabel('Eje x')
plt.ylabel('Eje y')
plt.grid(True)
plt.show()

# %% [markdown]
# # Función de Equilibrio de Mercado

# %%
x = np.linspace(0,10,100)
oferta = 2*x+5
demanda = -3*x+40

plt.plot(x, oferta, label='Oferta')
plt.plot(x, demanda, label='Demanda')
plt.title('Otro gráfico')
plt.xlabel('Eje X')
plt.ylabel('Eje Y')
plt.grid(True)
plt.show()

# %%
x = np.linspace(0,10,100)
oferta = 2*x+5
demanda = -3*x+40


plt.plot(x, oferta, label='Oferta')
plt.plot(x, demanda, label='Demanda')
plt.title('Función de Equilibrio de Mercado')
plt.xlabel('Cantidad')
plt.ylabel('Precio')

plt.axvline(7, color='red', linestyle='--')
plt.axhline(19, color='red', linestyle='--')

plt.legend()
#plt.grid(True)

plt.show()

# %%
# Oferta y demanda
x = np.linspace(0, 10, 100)
oferta = 2 * x + 5
demanda = -3 * x + 40

plt.plot(x, oferta, label='Oferta')
plt.plot(x, demanda, label='Demanda')
plt.title('Función de Equilibrio de Mercado')
plt.xlabel('Cantidad')
plt.ylabel('Precio')

plt.axvline(5, color='gray', linestyle='--')
plt.axhline(15, color='gray', linestyle='--')

plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # Función de Costo Marginal
# El Costo Marginal (MC, por sus siglas en inglés de "Marginal Cost") es una herramienta económica que mide el cambio en el costo total de producción cuando se produce una unidad adicional de un bien o servicio. Es una función fundamental en la teoría de la producción y se utiliza para optimizar las decisiones de producción y fijación de precios.
#
#
# Una forma común es
# 𝑀𝐶(𝑄)= 𝑐 + 𝑑 𝑄

# %%
import matplotlib.pyplot as plt
import numpy as np

# Parámetros de la función de costo marginal
c, d = 10, 2
Q = np.linspace(0, 10, 100)
MC = c + d * Q

plt.plot(Q, MC)
plt.title('Función de Costo Marginal')
plt.xlabel('Cantidad Producida (Q)')
plt.ylabel('Costo Marginal (MC)')
plt.grid(True)
plt.show()

# %% [markdown]
# # Subplots

# %%
#Generación de datos
x = np.linspace(-10, 10, 400)

y1 = 2 * x + 1
y2 = -x + 3
y3 = 0.5 * x *x - 2
y4 = 3 * x + 4

#Generar subplots
fig, axs = plt.subplots(2,2,figsize=(18,8))
# Función Lineal 1
axs[0, 0].plot(x, y1, 'b-')
axs[0, 0].set_title('y = 2x + 1')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('y')
axs[0, 0].grid(True)

# Función Lineal 2
axs[0, 1].plot(x, y2, 'r-')
axs[0, 1].set_title('y = -x + 3')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('y')
axs[0, 1].grid(True)

# Función Lineal 3
axs[1, 0].plot(x, y3, 'g-')
axs[1, 0].set_title('y = 0.5x*x - 2')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('y')
axs[1, 0].grid(True)

# Función Lineal 4
axs[1, 1].plot(x, y4, 'm-')
axs[1, 1].set_title('y = 3x + 4')
axs[1, 1].set_xlabel('x')
axs[1, 1].set_ylabel('y')
axs[1, 1].grid(True)
plt.tight_layout()

plt.show()

# %%
#import matplotlib.pyplot as plt
#import numpy as np

# Crear valores de x
x = np.linspace(-10, 10, 400)

# Definir las funciones lineales
y1 = 2 * x + 1
y2 = -x + 3
y3 = 0.5 * x *x - 2
y4 = 3 * x + 4

# Crear una figura con 4 subplots
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Función Lineal 1
axs[0, 0].plot(x, y1, 'b-')
axs[0, 0].set_title('y = 2x + 1')
axs[0, 0].set_xlabel('x')
axs[0, 0].set_ylabel('y')
axs[0, 0].grid(True)

# Función Lineal 2
axs[0, 1].plot(x, y2, 'r-')
axs[0, 1].set_title('y = -x + 3')
axs[0, 1].set_xlabel('x')
axs[0, 1].set_ylabel('y')
axs[0, 1].grid(True)

# Función Lineal 3
axs[1, 0].plot(x, y3, 'g-')
axs[1, 0].set_title('y = 0.5x*x - 2')
axs[1, 0].set_xlabel('x')
axs[1, 0].set_ylabel('y')
axs[1, 0].grid(True)

# Función Lineal 4
axs[1, 1].plot(x, y4, 'm-')
axs[1, 1].set_title('y = 3x + 4')
axs[1, 1].set_xlabel('x')
axs[1, 1].set_ylabel('y')
axs[1, 1].grid(True)

# Ajustar el layout para evitar superposiciones
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Gráfico de Dispersión

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# Simular datos de horas de estudio y calificaciones
np.random.seed(0)

horas_estudio = np.random.randint(1, 10, 50)
calificaciones = horas_estudio * 10 + np.random.normal(0, 5, 50)

# Crear un DataFrame con los datos
data = {
    'Horas de Estudio': horas_estudio,
    'Calificaciones': calificaciones
}
df = pd.DataFrame(data)
df
# Out:
#     Horas de Estudio  Calificaciones
# 0                  6       57.295419
# 1                  1        3.383863
# 2                  4       39.436005
# 3                  4       44.536730
# 4                  8       84.076350
# 5                  4       41.145490
# 6                  6       54.869106
# 7                  3       32.387627
# 8                  5       56.463491
# 9                  8       76.342709
# 10                 7       61.972989
# 11                 9       94.947381
# 12                 9       90.554073
# 13                 2       18.095343
# 14                 7       70.574796
# 15                 8       81.726563
# 16                 8       71.325206
# 17                 9       98.291756
# 18                 2       31.498858
# 19                 6       57.644324
# 20                 9       96.313577
# 21                 5       44.147423
# 22                 4       45.328946
# 23                 1        6.500313
# 24                 4       40.720396
# 25                 6       61.992711
# 26                 1       10.134346
# 27                 3       35.279186
# 28                 4       39.634083
# 29                 9       86.671397
# 30                 2       19.779438
# 31                 4       38.183665
# 32                 4       39.938276
# 33                 4       40.210607
# 34                 8       89.796479
# 35                 1        9.007872
# 36                 2       21.652672
# 37                 1        2.820858
# 38                 5       50.137642
# 39                 8       85.603023
# 40                 4       38.879806
# 41                 3       27.899083
# 42                 8       84.999148
# 43                 3       32.155171
# 44                 1        6.745436
# 45                 1        2.506298
# 46                 5       43.846825
# 47                 6       60.970036
# 48                 6       55.008088
# 49                 7       68.161812

# %%
# Crear una figura
plt.figure(figsize=(8, 4))

# Crear el gráfico de dispersión
plt.scatter(df['Horas de Estudio'], df['Calificaciones'], color='#8dd3c7', marker='o')

# Añadir título y etiquetas de los ejes
plt.title('Relación entre Horas de Estudio y Calificaciones')
plt.xlabel('Horas de Estudio')
plt.ylabel('Calificaciones')

# Añadir una cuadrícula
plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Gráfico Histograma

# %%
import matplotlib.pyplot as plt
import numpy as np

# (calificaciones de estudiantes)
np.random.seed(42)
calificaciones = np.random.normal(15, 5, 100)  # Media = 70, Desviación estándar = 10, Número de datos = 100

# Crear una figura
plt.figure(figsize=(10, 6))

# Crear el histograma
plt.hist(calificaciones, bins=5, edgecolor='gray')

# Añadir título y etiquetas de los ejes
plt.title('Distribución de Calificaciones de Estudiantes')
plt.xlabel('Calificaciones')
plt.ylabel('Frecuencia')

plt.grid(True)

# Mostrar el gráfico
plt.show()

# %% [markdown]
# # Box Plot

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

np.random.seed(42)

datos = {
    'Matemáticas': np.random.normal(70, 10, 100),
    'Ciencias': np.random.normal(65, 15, 100),
    'Inglés': np.random.normal(75, 12, 100)
}

df = pd.DataFrame(datos)
df
# Out:
#     Matemáticas   Ciencias     Inglés
# 0     74.967142  43.769439  79.293448
# 1     68.617357  58.690320  81.729414
# 2     76.476885  59.859282  87.996615
# 3     85.230299  52.965841  87.645625
# 4     67.658466  62.580714  58.467968
# ..          ...        ...        ...
# 95    55.364851  70.779761  66.685085
# 96    72.961203  51.742138  85.795199
# 97    72.610553  67.305877  78.687594
# 98    70.051135  65.873131  84.754345
# 99    67.654129  47.855446  82.555546
#
# [100 rows x 3 columns]

# %%
# Crear una figura
plt.figure(figsize=(10, 6))

# Crear el gráfico de cajas
sns.boxplot(data=df[['Matemáticas','Ciencias']])

# Añadir título y etiquetas de los ejes
plt.title('Distribución de Calificaciones por Asignatura')
plt.xlabel('Asignatura')
plt.ylabel('Calificaciones')

# Mostrar el gráfico
plt.show()

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Datosaurus
# Es un conjunto de datos creado para ilustrar la importancia de visualizar los datos en lugar de confiar únicamente en las estadísticas resumidas. El conjunto de datos original, conocido como "Datasaurus," fue diseñado para demostrar que diferentes conjuntos de datos pueden tener las mismas estadísticas descriptivas (media, varianza, correlación, etc.) pero pueden ser muy diferentes cuando se visualizan gráficamente.

# %%
# Conectar con Google Drive
#PATH = '/content/drive/MyDrive/CURSOS_UTEC/2024_0/Python_Data_Visualization/Clase 4_Cuantitativa I/Datos/Datasaurus_data.csv'
PATH = 'https://raw.githubusercontent.com/germaingarcia/Files_Lectures/main/Datasaurus_data.csv'

# %%
from IPython.display import display
import pandas as pd
import numpy as np
import xml.etree.ElementTree as ET

# Lee el archivo .csv
df = pd.read_csv(PATH)

# Muestra las primeras filas del DataFrame para verificar que se haya cargado correctamente
df
# Out:
#          dataset          x          y
# 0           dino  55.384600  97.179500
# 1           dino  51.538500  96.025600
# 2           dino  46.153800  94.487200
# 3           dino  42.820500  91.410300
# 4           dino  40.769200  88.333300
# ...          ...        ...        ...
# 1699  slant_down  39.596501  32.136132
# 1700  slant_down  95.593416  33.234129
# 1701  slant_down  52.772288  99.613472
# 1702  slant_down  53.178614  98.603861
# 1703  slant_down  37.627053  93.060673
#
# [1704 rows x 3 columns]

# %%
df_dino = df[df['dataset']=='dino']
df_dino
# Out:
#     dataset        x        y
# 0      dino  55.3846  97.1795
# 1      dino  51.5385  96.0256
# 2      dino  46.1538  94.4872
# 3      dino  42.8205  91.4103
# 4      dino  40.7692  88.3333
# ..      ...      ...      ...
# 137    dino  39.4872  25.3846
# 138    dino  91.2821  41.5385
# 139    dino  50.0000  95.7692
# 140    dino  47.9487  95.0000
# 141    dino  44.1026  92.6923
#
# [142 rows x 3 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

df_dino = df[df['dataset']=='dino']
plt.scatter(df_dino['x'], df_dino['y'], color='#fb8072', marker='o',edgecolor='gray')

plt.grid(True)
# Mostrar el gráfico
plt.show()

# %%
axes = axes.flatten()
axes
# Out:
# array([<Axes: title={'center': 'dino'}, xlabel='x', ylabel='y'>,
#        <Axes: title={'center': 'away'}, xlabel='x', ylabel='y'>,
#        <Axes: title={'center': 'h_lines'}, xlabel='x', ylabel='y'>,
#        <Axes: title={'center': 'v_lines'}, xlabel='x', ylabel='y'>,
#        <Axes: title={'center': 'x_shape'}, xlabel='x', ylabel='y'>,
#        <Axes: title={'center': 'star'}, xlabel='x', ylabel='y'>,
#        <Axes: title={'center': 'high_lines'}, xlabel='x', ylabel='y'>,
#        <Axes: title={'center': 'dots'}, xlabel='x', ylabel='y'>,
#        <Axes: title={'center': 'circle'}, xlabel='x', ylabel='y'>,
#        <Axes: title={'center': 'bullseye'}, xlabel='x', ylabel='y'>,
#        <Axes: title={'center': 'slant_up'}, xlabel='x', ylabel='y'>,
#        <Axes: title={'center': 'slant_down'}, xlabel='x', ylabel='y'>],
#       dtype=object)

# %%
datasets = df['dataset'].unique()
datasets
# Out:
# array(['dino', 'away', 'h_lines', 'v_lines', 'x_shape', 'star',
#        'high_lines', 'dots', 'circle', 'bullseye', 'slant_up',
#        'slant_down'], dtype=object)

# %% [markdown]
# ##  1. Cargar y visualizar el conjunto de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

print(df.head())

datasets = df['dataset'].unique()

# Crear la figura y los subplots
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(14, 10))
axes = axes.flatten()

# Mapear los datos en cada subplot
for i, dataset in enumerate(datasets):
    subset = df[df['dataset'] == dataset]
    axes[i].scatter(subset['x'], subset['y'], color='red', marker='o',edgecolor='white')
    axes[i].set_title(dataset)
    axes[i].set_xlabel('x')
    axes[i].set_ylabel('y')

# Ajustar el diseño para evitar solapamientos
plt.tight_layout(rect=[0, 0, 1, 0.96])

# Ajustar el título
fig.suptitle('Datasaurus Dozen: Conjuntos de Datos Diferentes con Estadísticas Resumidas Idénticas', fontsize=16)

# Mostrar el gráfico
plt.show()
# Out:
#   dataset        x        y
# 0    dino  55.3846  97.1795
# 1    dino  51.5385  96.0256
# 2    dino  46.1538  94.4872
# 3    dino  42.8205  91.4103
# 4    dino  40.7692  88.3333

# %% [markdown]
# ##  2. Histograms for the x and y coordinates for one of the datasets:

# %%
dino_data = df[df['dataset'] == 'dino']


fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Histograma para los valores de 'x'
axes[0].hist(dino_data['x'], bins=10, color='green',edgecolor='white')
axes[0].set_title('Histogram of x values for dino dataset')
axes[0].set_xlabel('x values')
axes[0].set_ylabel('Frequency')

# Histograma para los valores de 'y'
axes[1].hist(dino_data['y'], bins=10, edgecolor='black')
axes[1].set_title('Histogram of y values for dino dataset')
axes[1].set_xlabel('y values')
axes[1].set_ylabel('Frequency')

# Ajustar el diseño para evitar solapamientos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## 3. Subplots para comparar diagramas de dispersión de algunos conjuntos de datos uno al lado del otro

# %%
datasets = ['dino', 'dots', 'x_shape']

fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for ax, dataset in zip(axes, datasets):
    data = df[df['dataset'] == dataset]
    ax.scatter(data['x'], data['y'])
    ax.set_title(f'Scatter plot para {dataset}')
    ax.set_xlabel('x')
    ax.set_ylabel('y')

# Ajustar el diseño para evitar solapamientos
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## 4. Box plot para todas las variables X de los diferentes datasets:

# %%
data_to_plot = [df[df['dataset'] == dataset]['x'] for dataset in datasets]

# %%
# Crear un box plot de la variable 'x' para todos los datasets
plt.figure(figsize=(12, 6))
datasets = df['dataset'].unique()

# Crear una lista de listas para los datos de 'x'
data_to_plot = [df[df['dataset'] == dataset]['x'] for dataset in datasets]

plt.boxplot(data_to_plot, labels=datasets,patch_artist=True)

plt.title('Box Plot de la Variable X en Todos los Datasets')
plt.xlabel('Dataset')
plt.ylabel('X')
plt.xticks(rotation=45)

plt.show()
# Out:
# <ipython-input-39-4c01178e0fd8>:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data_to_plot, labels=datasets,patch_artist=True)

# %% [markdown]
# ## 5. Box plot para todas las variables Y de los diferentes datasets:

# %%
# Crear un box plot de la variable 'y' para todos los datasets
import seaborn as sns
plt.figure(figsize=(12, 6))
sns.boxplot(x='dataset', y='y', data=df)
plt.title('Box Plot de la Variable Y en Todos los Datasets')
plt.xlabel('Dataset')
plt.ylabel('Y')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 6. Box plot para cada conjunto de datos:

# %%
# Configurar el estilo de los gráficos
sns.set(style="whitegrid")

# Crear una figura y un conjunto de subplots
fig, axs = plt.subplots(nrows=3, ncols=4, figsize=(20, 15))
fig.suptitle('Box Plots del Datasaurus Dozen', fontsize=20)

# Lista de nombres únicos de los datasets en el Datasaurus Dozen
datasets = df['dataset'].unique()

# Crear un box plot para cada dataset
for ax, dataset in zip(axs.flatten(), datasets):
    sns.boxplot(x='dataset', y='y', data=df[df['dataset'] == dataset], ax=ax)
    ax.set_title(dataset)
    ax.set_xlabel('')
    ax.set_ylabel('')

# Ajustar el layout para que no se solapen los gráficos
plt.tight_layout()
plt.subplots_adjust(top=0.95)
plt.show()
